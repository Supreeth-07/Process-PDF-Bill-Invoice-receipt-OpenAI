# %%
path = r"D:\Python Projects\6-RAG_on_Docs\Data\Z.Test-nw\1.Mideast Shp Mgt.pdf"
path5 = r"D:\Zzz.PROJECTS\AGOS\P2 - AirWay Bill - DU\MAWB 369-8944 4246.pdf"
path_op = r'D:\\Python Projects\\6-RAG_on_Docs\\Data\\Z.Test-nw\\1.Mideast Shp Mgt-2.pdf'
path_op2 = f'D:\\Python Projects\\6-RAG_on_Docs\\Data\\Z.Test-nw\\1.Mideast Shp Mgt-3.pdf'

# %%
from PyPDF2 import PdfReader, PdfWriter

# Path to your PDF
input_pdf_path = path_op
output_pdf_path = path_op2

# Pages you want to extract (1-based indexing)
pages_to_extract = [2]  # Extract pages 1, 3, and 5

# Read the PDF
reader = PdfReader(input_pdf_path)

for page_number in pages_to_extract:
    # PdfReader uses 0-based indexing, so subtract 1
    page = reader.pages[page_number - 1]
    
    writer = PdfWriter()
    writer.add_page(page)
    
    # output_pdf_path = f"page_{page_number}.pdf"
    # with open(output_pdf_path, "wb") as output_pdf:
    #     writer.write(output_pdf)

    with open(output_pdf_path, "wb") as output_pdf:
        writer.write(output_pdf)
    
    print(f"Saved: {output_pdf_path}")
# Out:
# Saved: D:\Python Projects\6-RAG_on_Docs\Data\Z.Test-nw\1.Mideast Shp Mgt-3.pdf

# %%
# pip install langchain langchain-community pypdf

# %%
path = r"D:\Python Projects\6-RAG_on_Docs\Data\Z.Test-nw\1.Mideast Shp Mgt.pdf"
path5 = r"D:\Zzz.PROJECTS\AGOS\P2 - AirWay Bill - DU\MAWB 369-8944 4246.pdf"
path_op = r'D:\\Python Projects\\6-RAG_on_Docs\\Data\\Z.Test-nw\\1.Mideast Shp Mgt-2.pdf'

# %%
pip install -U docling

# %%
path_op3 = r"D:\Python Projects\6-RAG_on_Docs\Data\Z.Test-nw\1.Mideast Shp Mgt-3.pdf"

# %%
from docling.document_converter import DocumentConverter

source = path_op3  # file path or URL
converter = DocumentConverter()
doc = converter.convert(source).document

#print(doc.export_to_markdown())  # output: "### Docling Technical Report[...]"

#print(doc.export_to_json())

#doc2 = converter.convert(source).input.file.stem
# Out:
# 2025-10-31 14:12:05,679 - INFO - detected formats: [<InputFormat.PDF: 'pdf'>]
# 2025-10-31 14:12:05,695 - INFO - Going to convert document batch...
# 2025-10-31 14:12:05,699 - INFO - Initializing pipeline for StandardPdfPipeline with options hash 4f2edc0f7d9bb60b38ebfecf9a2609f5
# 2025-10-31 14:12:05,707 - INFO - rapidocr cannot be used because onnxruntime is not installed.
# 2025-10-31 14:12:05,716 - INFO - easyocr cannot be used because it is not installed.
# 2025-10-31 14:12:05,732 - INFO - Accelerator device: 'cpu'
# [INFO] 2025-10-31 14:12:05,936 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-31 14:12:06,095 [RapidOCR] download_file.py:60: File exists and is valid: D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-10-31 14:12:06,098 [RapidOCR] torch.py:54: Using D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_det_infer.pth
# [INFO] 2025-10-31 14:12:15,512 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-31 14:12:15,526 [RapidOCR] download_file.py:60: File exists and is valid: D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2025-10-31 14:12:15,529 [RapidOCR] torch.py:54: Using D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_infer.pth
# [INFO] 2025-10-31 14:12:16,104 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2025-10-31 14:12:16,330 [RapidOCR] download_file.py:60: File exists and is valid: D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# [INFO] 2025-10-31 14:12:16,333 [RapidOCR] torch.py:54: Using D:\Python Projects\6-RAG_on_Docs\venv\Lib\site-packages\rapidocr\models\ch_PP-OCRv4_rec_infer.pth
# 2025-10-31 14:12:17,383 - INFO - Auto OCR model selected rapidocr with torch.
# 2025-10-31 14:12:17,386 - INFO - Accelerator device: 'cpu'
# 2025-10-31 14:12:20,644 - INFO - Accelerator device: 'cpu'
# 2025-10-31 14:12:23,410 - INFO - Processing document 1.Mideast Shp Mgt-3.pdf
# 2025-10-31 14:12:32,256 - INFO - Finished converting document 1.Mideast Shp Mgt-3.pdf in 26.58 sec.

# %%
doc.pages
# Out:
# {1: PageItem(size=Size(width=595.0, height=841.0), image=None, page_no=1)}

# %%
print(doc.export_to_markdown())
# Out:
# - BATTERY RECHARGEABLE R14, 1.2V 1200MAH 2'S/PKT 8
#
# 792455
#
# 2.00
#
# PKT
#
# Details : Rechargeable batteries can be brought back to life hundreds of times and are completely sealed and free from leakage.  They have good temperature characteristics and superior voltage regulation at either high or low discharge currents.  They are the same size as ordinary dry cells but can be employed at a minimum cost and maximum convenience for a wide variety of uses.  Necessary recharging time is 14 - 16 hours.
#
# - BATTERY RECHARGEABLE 6F22, 9V 75MAH 9
#
# 792457
#
# 3.00
#
# PCS
#
# Details : Rechargeable batteries can be brought back to life hundreds of times and are completely sealed and free from leakage.  They have good temperature characteristics and superior voltage regulation at either high or low discharge currents.  They are the same size as ordinary dry cells but can be employed at a minimum cost and maximum convenience for a wide variety of uses.  Necessary recharging time is 14 - 16 hours.
#
# - LAMP SINGLE LED INDICATOR BA9S,6V WHITE 10
#
# 790733
#
# 30.00
#
# PC
#
# Details : Single LED indicator lamp white , bayonet ba9s, 6 Volt
#
# - LAMP SINGLE LED INDICATOR BA9S,24-28V WHITE 11
#
# 790774
#
# 30.00
#
# PC
#
# Details : Single LED indicator lamp white , bayonet ba9s, 24-28 Volt
#
# - LAMP SINGLE LED INDICATOR E10,24-28V WHITE 12
#
# 790891
#
# 30.00
#
# PC
#
# Details : Single LED indicator lamp white , edison E10, 24-28 Volt
#
# - TIP #7535 REGULAR FOR CORDLESS, SOLDERING IRON #7800 13
#
# 795002
#
# 2.00
#
# PCS
#
# Details : A cordless portable soldering iron heated by a nickel cadmium  2.5V rechargeable battery.  About 200 soldering jobs can be performed at one time in one hour of quick charging.  Separate battery charger operates charging automatically when the iron is placed on it.  The pilot lamp of the iron helps when working in dark places.  A set includes a charger and two fine tips (No. 7545, No. 7577).  For further information, please write or ask for a catalogue.
#
# - TIP #7545 FINE FOR CORDLESS, SOLDERING IRON #7800 14
#
# 795003
#
# 2.00
#
# PCS
#
# Details : A cordless portable soldering iron heated by a nickel cadmium  2.5V rechargeable battery.  About 200 soldering jobs can be performed at one time in one hour of quick charging.  Separate battery charger operates charging automatically when the iron is placed on it.  The pilot lamp of the iron helps when working in dark places.  A set includes a charger and two fine tips (No. 7545, No. 7577).  For further information, please write or ask for a catalogue.
#
# - TIP #7546 HEAVY FOR CORDLESS, SOLDERING IRON #7800 15
#
# 795004
#
# 2.00
#
# PCS
#
# Details : A cordless portable soldering iron heated by a nickel cadmium  2.5V rechargeable battery.  About 200 soldering jobs can be performed at one time in one hour of quick charging.  Separate battery charger operates charging automatically when the iron is placed on it.  The pilot lamp of the iron helps when working in dark places.  A set includes a charger and two fine tips (No. 7545, No. 7577).  For further information, please write or ask for a catalogue.
#
# - TIP #7566 MICRO FOR CORDLESS, SOLDERING IRON #7800 16
#
# 795005
#
# 2.00
#
# PCS
#
# Details : A cordless portable soldering iron heated by a nickel cadmium  2.5V rechargeable battery.  About 200 soldering jobs can be performed at one time in one hour of quick charging.  Separate battery charger operates charging automatically when the iron is placed on it.  The pilot lamp of the iron helps when working in dark places.  A set includes a charger and two fine tips (No. 7545, No. 7577).  For further information, please write or ask for a catalogue.
#
# - CABLE CABTYRE NATURAL RUBBER, SHEATHED 1CT 2.0MM/SQ.X3C 17
#
# 794133
#
# 100.00
#
# MTR
#
# Details : Designed for electric tools and lighting fixtures.  Natural rubber sheath encloses each conductor.  Conductors completed with natural rubber sheath as a final seal.  Fixed length is 200 mtrs/coil.
#
# - CABLE CABTYRE NATURAL RUBBER, SHEATHED 1CT 1.25MM/SQ.X3C 18
#
# 794132
#
# 100.00
#
# MTR
#
# Details : Designed for electric tools and lighting fixtures.  Natural rubber sheath encloses each conductor.  Conductors completed with natural rubber sheath as a final seal.  Fixed length is 200 mtrs/coil.
#
# - CABLE CABTYRE P.V.C. SHEATHED, 2.0MM/SQX3C 19
#
# 794178
#
# 100.00
#
# MTR
#
# Details : For portable electric tools or wiring work.  Each wire is covered with vinyl and an exterior vinyl sheath.  Fixed length is 200 mtrs/coil.
#
# - CABLE CABTYRE P.V.C. SHEATHED, 1.25MM/SQX3C 20
#
# 794177
#
# 100.00
#
# MTR
#
# Details : For portable electric tools or wiring work.  Each wire is covered with vinyl and an exterior vinyl sheath.  Fixed length is 200 mtrs/coil.
#
# - BATTERY  LITHIUM HIGH ENERGY 3.6V, 2/3AA, ER14335 21
#
# 79241*
#
# 5.00
#
# PCS
#
# Details : Type ER 14335, Size 2/3AA
#
# ## Special Instructions:
#
# - #1. To supply OSRAM brand substitube ST8E-1.2M, 865 daylight, 18W, 220-240V EM.
# - #2. To supply OSRAM brand Substitube ST8E-0.6M daylight, 9W, 220-240V EM.
# - #14. To supply LED bulbs equivalent to 60W - 75W power bulb.
# - #21. To supply Fluke make.
# - #37. Required for BWTS room portable gas detector.
#
# ## Terms and Conditions:
#
# 1. This Purchase Order is subject to Mideast Ship Management Standard Terms and Conditions of Purchase, as per the link.
#
# https://www.bahri.sa/media/utrdlhaz/bsm-standard-terms-conditions.pdf
#
# 2. Contractor's personnel boarding Mideast Vessels for executing contracted work on board shall be required to sign a HSE Obligation undertaking (as per the link)
#
# https://www.bahri.sa/media/bqbhgafb/form-108-contractor-hse-obligation.pdf
#
# 3. Vendor must comply with the cyber security guidelines, including the defined controls related to data protection, as specified in Clause 17 of the Standard Terms &amp; Conditions of Purchase. Vendor must strictly follow the requirements on all aspects

# %%
import logging
import time
from pathlib import Path

import pandas as pd

from docling.document_converter import DocumentConverter





doc_converter = DocumentConverter()

conv_res = doc_converter.convert(path_op)

doc_filename = conv_res.input.file.stem

# Export tables
for table_ix, table in enumerate(conv_res.document.tables):
        table_df: pd.DataFrame = table.export_to_dataframe()
        print(f"## Table {table_ix}")
        print(table_df.to_markdown())



    #     # Save the table as CSV
    #     element_csv_filename = output_dir / f"{doc_filename}-table-{table_ix + 1}.csv"
    #     _log.info(f"Saving CSV table to {element_csv_filename}")
    #     table_df.to_csv(element_csv_filename)

    #     # Save the table as HTML
    #     element_html_filename = output_dir / f"{doc_filename}-table-{table_ix + 1}.html"
    #     _log.info(f"Saving HTML table to {element_html_filename}")
    #     with element_html_filename.open("w") as fp:
    #         fp.write(table.export_to_html(doc=conv_res.document))

    # end_time = time.time() - start_time

# %%
table_df

# %%
from docling.datamodel.base_models import InputFormat
from docling.document_extractor import DocumentExtractor

# initialize extractor, allow PDF
extractor = DocumentExtractor(allowed_formats=[InputFormat.PDF])

# define template: for example you want “invoice_number” and “total_amount”
template = {
    "Enquiry Ref.": "string",
    "Vessel.": "string",
    "Order Title.": "string"
}

# provide your PDF path
source = path_op

# run extraction
result = extractor.extract(source=source, template=template)

# inspect results
for page in result.pages:
    print(f"Page {page.page_no}: {page.extracted_data}")

# %%
for page_idx, page in enumerate(doc.pages):
    # create a new document representation for each page if needed
    # e.g., serialize page, or wrap it, or treat each page as its own doc
    page_doc = page  # or some wrapper, depending on your downstream needs
    print(f"Page {page_idx+1}: {page}")

# %%
len(doc.texts)

# %%
doc.export_to_markdown

# %%
print(doc.export_to_markdown())

# %%
import camelot

# 'lattice' or 'stream'

# Choose "lattice" if tables have borders, else "stream"
tables = camelot.read_pdf(path4, pages="all", flavor='lattice')
combined_df2 = pd.concat([table.df for table in tables], ignore_index=True)

print(combined_df2.to_string())

# %%
import pikepdf

# Open a PDF
pdf = pikepdf.open(path)

# Print document metadata
print(pdf.docinfo)

# Extract the first _ pages into a new PDF
new_pdf = pikepdf.Pdf.new()
for page in pdf.pages:
    new_pdf.pages.append(page)

new_pdf.save(path_op)
pdf.close()
new_pdf.close()
