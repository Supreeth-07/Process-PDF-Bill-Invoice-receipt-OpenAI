# %%
path1 = r"D:\Python Projects\z-PDF data extraction issues\MOL DATA (1)\8. MetroMac Marine AED 4840_FJ2025090049.pdf"
#MetroMac Marine 
path2 = 

path3 = 

path4 = 

path5 = 

path6 =
# Out:
#   Cell In[2], line 2
#     path2 =
#             ^
# SyntaxError: invalid syntax
